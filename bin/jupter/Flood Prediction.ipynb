# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import os 
for dirname, filenames in os.walk('/E:/Github/Develop-a-Water-Quality-Index-WQI-Prediction'):
    for filename in filenames:
        print(os.path.join(dirname,filename))

import warnings
warnings.filterwarnings('ignore')

# %%
pip install seaborn
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# path = 'E:\Github\Develop-a-Water-Quality-Index-WQI-Prediction\Water-Quality-Index-Prediction\datasets/train.csv'
path = "../../datasets/train.csv"

# %%
df = pd.read_csv(path)
df.head(5)
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
df.shape
# Out:
# (1117957, 22)

# %%
df.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of               id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0              0                 5                   8                5
# 1              1                 6                   7                4
# 2              2                 6                   5                6
# 3              3                 3                   4                6
# 4              4                 5                   3                2
# ...          ...               ...                 ...              ...
# 1117952  1117952                 3                   3                4
# 1117953  1117953                 2                   2                4
# 1117954  1117954                 7                   3                9
# 1117955  1117955                 7                   3                3
# 1117956  1117956                 4                   5                6
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.describe().T
# Out:
#                                      count      mean       std    min   25%  \
# MonsoonIntensity                 1117957.0  4.921450  2.056387  0.000  3.00
# TopographyDrainage               1117957.0  4.926671  2.093879  0.000  3.00
# RiverManagement                  1117957.0  4.955322  2.072186  0.000  4.00
# Deforestation                    1117957.0  4.942240  2.051689  0.000  4.00
# Urbanization                     1117957.0  4.942517  2.083391  0.000  3.00
# ClimateChange                    1117957.0  4.934093  2.057742  0.000  3.00
# DamsQuality                      1117957.0  4.955878  2.083063  0.000  4.00
# Siltation                        1117957.0  4.927791  2.065992  0.000  3.00
# AgriculturalPractices            1117957.0  4.942619  2.068545  0.000  3.00
# Encroachments                    1117957.0  4.949230  2.083324  0.000  4.00
# IneffectiveDisasterPreparedness  1117957.0  4.945239  2.078141  0.000  3.00
# ...

# %%
nrows = (len(df.columns) + 2) // 3  # 3 graphs per row
ncols = min(len(df.columns), 3)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 5 * nrows))

# Flatten axes if necessary
if nrows == 1:
    axes = [axes]

# Plot distribution for each feature
for i, col in enumerate(df.columns):
    row_index = i // ncols
    col_index = i % ncols
    ax = axes[row_index][col_index]
    sns.histplot(df[col],bins=40, kde=True, ax=ax)
    ax.set_title(col + ' Distribution')
    ax.set_ylabel('Frequency')
    ax.set_xlabel(col)

# Remove empty subplots if ncols * nrows > number of features
if nrows * ncols > len(df.columns):
    for i in range(len(df.columns), nrows * ncols):
        fig.delaxes(axes.flatten()[i])

plt.tight_layout()
plt.show();

# %%
target_column = 'FloodProbability'
nrows = (len (df.columns) -1+2) // 3
ncols = min (len(df.columns) - 1, 3)
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize =(15, 5 * nrows))
if nrows == 1:
    axes = [axes]

for i, col in enumerate (df.columns):
    if col == target_column:
        continue
    row_index = i // ncols
    col_index = i % ncols
    ax = axes [row_index] [col_index]
    sns.scatterplot(x = df[col], y = df [target_column], ax = ax)
    ax.set_title (f'{col} vs {target_column}')
    ax.set_xlabel(col)
    ax.set_ylabel(target_column)
                    
if nrows * ncols > len(df.columns) - 1:
    for i in range (nrows * ncols, (len(df.columns)-1)):
        fig.delaxes(axes.flatten()[i])
plt.tight_layout ()
plt.show();

# %%
plt.figure(figsize =(15,10))
sns.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = 'coolwarm', vmax =1, vmin = -1)
plt.xticks(rotation = 45)
plt.yticks(rotation = 0)
plt.title ("Correlation Heatmap")
plt.show()

# %%
#split data
x = df.drop(columns= ['FloodProbability'])
y = df['FloodProbability']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split (x,y,train_size= 0.85, random_state=0 )

# %%
from sklearn.linear_model import LinearRegression
Lr = LinearRegression ()

# %%
Lr.fit(x_train, y_train)
print (Lr)
# Out:
# LinearRegression()

# %%
y_pred_Lr_train = Lr.predict(x_train)
y_pred_Lr = Lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

# %%
error_train= mean_absolute_percentage_error (y_train, y_pred_Lr_train)
print ('Train error of linear regression Model = %.2f' %(error_train * 100), '%')
print ('Train accuracy of Linear Regression Model = %.2f' %((1-error_train)*100),'%')
# Out:
# Train error of linear regression Model = 3.19 %
# Train accuracy of Linear Regression Model = 96.81 %

# %%
error = mean_absolute_percentage_error (y_test, y_pred_Lr)
print ('Error of linear regression Model = %.2f' %(error * 100), '%')
print ('Accuracy of Linear Regression Model = %.2f' %((1-error)*100),'%')
# Out:
# Error of linear regression Model = 3.19 %
# Accuracy of Linear Regression Model = 96.81 %

# %%
r2 =  r2_score(y_test, y_pred_Lr)
print("R2 score of Linear Regression = %.2f" %(r2))
# Out:
# R2 score of Linear Regression = 0.84
